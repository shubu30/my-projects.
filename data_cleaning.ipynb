# %%
import pandas as pd
import os

# %%
ds = pd.read_excel(r"Customer Call List.xlsx")

# %%
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
ds.delete_column('Not_Useful_Column',inplace = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8940\2249239436.py in ?()
# ----> 1 ds.delete_column('Not_Useful_Column',inplace = True)
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'delete_column'

# %%
ds.drop_duplicates(inplace = True)

# %%
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
ds.drop(columns=['Not_Useful_Column'], inplace=True)

# %%
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
ds["Do_Not_Contact"].str.replace('Y','Yes')
# Out:
# 0        No
# 1     Yeses
# 2       NaN
# 3       Yes
# 4        No
# 5     Yeses
# 6        No
# 7        No
# 8       NaN
# 9        No
# 10       No
# 11      NaN
# 12        N
# 13       No
# 14       No
# 15        N
# 16       No
# 17      NaN
# 18    Yeses
# 19        N
# Name: Do_Not_Contact, dtype: object

# %%
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
ds["Do_Not_Contact"] = ds["Do_Not_Contact"].str.replace('Yes','Y')

# %%
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
ds["Do_Not_Contact"] = ds["Do_Not_Contact"].str.replace('No','N')

# %%
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
ds["Phone_Number"] = ds["Phone_Number"].str.replace('123','456')

ds["Phone_Number"] = ds["Phone_Number"].str.replace('Na--','')
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  456-545-5421
# 1         1002       Abed        Nadir  456/643/9775
# 2         1003     Walter       /White           NaN
# 3         1004     Dwight      Schrute  456-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  456-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter           NaN
# 12        1013        Don       Draper  456-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  456-545-5421
# 16        1017   Michael         Scott  456/643/9775
# ...

# %%
ds[["Street_Address", "State", "Zip_Code"]] = ds["Address"].str.split(',', n=2, expand=True)
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  456-545-5421
# 1         1002       Abed        Nadir  456/643/9775
# 2         1003     Walter       /White           NaN
# 3         1004     Dwight      Schrute  456-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  456-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter           NaN
# 12        1013        Don       Draper  456-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  456-545-5421
# 16        1017   Michael         Scott  456/643/9775
# ...

# %%
ds["State"] = ds["State"].str.replace('None','Not Avl')

# %%
ds["State"] = ds["State"].fillna('Not Avl')
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  456-545-5421
# 1         1002       Abed        Nadir  456/643/9775
# 2         1003     Walter       /White           NaN
# 3         1004     Dwight      Schrute  456-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  456-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter           NaN
# 12        1013        Don       Draper  456-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  456-545-5421
# 16        1017   Michael         Scott  456/643/9775
# ...

# %%
ds["Zip_Code"] = ds["Zip_Code"].fillna('Not Avl')

# %%
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  456-545-5421
# 1         1002       Abed        Nadir  456/643/9775
# 2         1003     Walter       /White           NaN
# 3         1004     Dwight      Schrute  456-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  456-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter           NaN
# 12        1013        Don       Draper  456-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  456-545-5421
# 16        1017   Michael         Scott  456/643/9775
# ...

# %%
ds.drop_column('Do_Not_Contact')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8940\666107821.py in ?()
# ----> 1 ds.drop_column('Do_Not_Contact')
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'drop_column'

# %%
ds.drop(columns=['Do_Not_Contact'], inplace=True)

# %%
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  456-545-5421
# 1         1002       Abed        Nadir  456/643/9775
# 2         1003     Walter       /White           NaN
# 3         1004     Dwight      Schrute  456-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  456-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter           NaN
# 12        1013        Don       Draper  456-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  456-545-5421
# 16        1017   Michael         Scott  456/643/9775
# ...

# %%
ds=ds.fillna('')
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  456-545-5421
# 1         1002       Abed        Nadir  456/643/9775
# 2         1003     Walter       /White
# 3         1004     Dwight      Schrute  456-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf                        N/a
# 9         1010      Peter       Parker  456-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter
# 12        1013        Don       Draper  456-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  456-545-5421
# 16        1017   Michael         Scott  456/643/9775
# 17        1018      Clark         Kent
# ...

# %%
ds["Phone_Number"] = ds["Phone_Number"].str.replace('nan--','')

ds["Phone_Number"] = ds["Phone_Number"].str.replace('Na--','')
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  456-545-5421
# 1         1002       Abed        Nadir  456/643/9775
# 2         1003     Walter       /White
# 3         1004     Dwight      Schrute  456-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf                        N/a
# 9         1010      Peter       Parker  456-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter
# 12        1013        Don       Draper  456-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  456-545-5421
# 16        1017   Michael         Scott  456/643/9775
# 17        1018      Clark         Kent
# ...

# %%
ds["Phone_Number"] = ds["Phone_Number"].str.replace('/','-')

# %%
ds["Phone_Number"] = ds["Phone_Number"].str.replace('|','-')

# %%
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  456-545-5421
# 1         1002       Abed        Nadir  456-643-9775
# 2         1003     Walter       /White
# 3         1004     Dwight      Schrute  456-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf                        N-a
# 9         1010      Peter       Parker  456-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter
# 12        1013        Don       Draper  456-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  456-545-5421
# 16        1017   Michael         Scott  456-643-9775
# 17        1018      Clark         Kent
# ...

# %%
ds["Phone_Number"] = ds["Phone_Number"].str.replace('N-a','')

# %%
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  456-545-5421
# 1         1002       Abed        Nadir  456-643-9775
# 2         1003     Walter       /White
# 3         1004     Dwight      Schrute  456-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter       Parker  456-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter
# 12        1013        Don       Draper  456-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  456-545-5421
# 16        1017   Michael         Scott  456-643-9775
# 17        1018      Clark         Kent
# 18        1019      Creed       Braton
# ...

# %%
ds["Last_Name"] = ds["Last_Name"].str.replace('/','')

# %%
ds["Last_Name"] = ds["Last_Name"].str.replace('...','')

# %%
ds
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  456-545-5421
# 1         1002       Abed        Nadir  456-643-9775
# 2         1003     Walter        White
# 3         1004     Dwight      Schrute  456-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter       Parker  456-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry       Potter
# 12        1013        Don       Draper  456-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  456-545-5421
# 16        1017   Michael         Scott  456-643-9775
# 17        1018      Clark         Kent
# 18        1019      Creed       Braton
# ...

# %%
ds["Last_Name"] = ds["Last_Name"].str.replace('_','')

# %%
ds
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  456-545-5421
# 1         1002       Abed       Nadir  456-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  456-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  456-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  456-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  456-545-5421
# 16        1017   Michael        Scott  456-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
ds["Paying Customer"] = ds["Paying Customer"].str.replace('Yes','Y')

# %%
ds["Paying Customer"] = ds["Paying Customer"].str.replace('N/a','Not Avl')

# %%
ds
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  456-545-5421
# 1         1002       Abed       Nadir  456-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  456-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  456-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  456-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  456-545-5421
# 16        1017   Michael        Scott  456-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
ds = ds.replace('N/a','Not Avl')

# %%
ds
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  456-545-5421
# 1         1002       Abed       Nadir  456-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  456-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  456-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  456-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  456-545-5421
# 16        1017   Michael        Scott  456-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
for x in ds.index:
    if ds.loc[x, "Paying Customer"] == 'Y':
        ds.drop(x, inplace=True)

ds
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 1         1002       Abed       Nadir  456-643-9775   93 West Main Street
# 2         1003     Walter       White                  298 Drugs Driveway
# 6         1007       Jeff      Winger                   1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 14        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 15        1016        Ron     Weasley  456-545-5421  2395 Hogwarts Avenue
# 18        1019      Creed      Braton                             Not Avl
#
#    Paying Customer        Street_Address    State Zip_Code
# 1               No   93 West Main Street  Not Avl  Not Avl
# 2                N    298 Drugs Driveway  Not Avl  Not Avl
# 6               No     1209 South Street  Not Avl  Not Avl
# 7                N         98 Clue Drive  Not Avl  Not Avl
# 14               N         214 HR Avenue  Not Avl  Not Avl
# ...

# %%
ds = ds.reset_index()
ds
# Out:
#    index  CustomerID First_Name   Last_Name  Phone_Number  \
# 0      1        1002       Abed       Nadir  456-643-9775
# 1      2        1003     Walter       White
# 2      6        1007       Jeff      Winger
# 3      7        1008   Sherlock      Holmes  876-678-3469
# 4     14        1015       Toby  Flenderson  304-762-2467
# 5     15        1016        Ron     Weasley  456-545-5421
# 6     18        1019      Creed      Braton
#
#                 Address Paying Customer        Street_Address    State  \
# 0   93 West Main Street              No   93 West Main Street  Not Avl
# 1    298 Drugs Driveway               N    298 Drugs Driveway  Not Avl
# 2     1209 South Street              No     1209 South Street  Not Avl
# 3         98 Clue Drive               N         98 Clue Drive  Not Avl
# 4         214 HR Avenue               N         214 HR Avenue  Not Avl
# 5  2395 Hogwarts Avenue              No  2395 Hogwarts Avenue  Not Avl
# ...

# %%
for x in ds.index:
    if ds.loc[x, "Phone_Number"] == '':
        ds.drop(x, inplace=True)

ds
# Out:
#    index  CustomerID First_Name   Last_Name  Phone_Number  \
# 0      1        1002       Abed       Nadir  456-643-9775
# 3      7        1008   Sherlock      Holmes  876-678-3469
# 4     14        1015       Toby  Flenderson  304-762-2467
# 5     15        1016        Ron     Weasley  456-545-5421
#
#                 Address Paying Customer        Street_Address    State  \
# 0   93 West Main Street              No   93 West Main Street  Not Avl
# 3         98 Clue Drive               N         98 Clue Drive  Not Avl
# 4         214 HR Avenue               N         214 HR Avenue  Not Avl
# 5  2395 Hogwarts Avenue              No  2395 Hogwarts Avenue  Not Avl
#
#   Zip_Code
# 0  Not Avl
# 3  Not Avl
# 4  Not Avl
# 5  Not Avl

# %%
ds = ds.reset_index()
ds
# Out:
#    level_0  index  CustomerID First_Name   Last_Name  Phone_Number  \
# 0        0      1        1002       Abed       Nadir  456-643-9775
# 1        3      7        1008   Sherlock      Holmes  876-678-3469
# 2        4     14        1015       Toby  Flenderson  304-762-2467
# 3        5     15        1016        Ron     Weasley  456-545-5421
#
#                 Address Paying Customer        Street_Address    State  \
# 0   93 West Main Street              No   93 West Main Street  Not Avl
# 1         98 Clue Drive               N         98 Clue Drive  Not Avl
# 2         214 HR Avenue               N         214 HR Avenue  Not Avl
# 3  2395 Hogwarts Avenue              No  2395 Hogwarts Avenue  Not Avl
#
#   Zip_Code
# 0  Not Avl
# 1  Not Avl
# 2  Not Avl
# 3  Not Avl

# %%
ds.drop(columns=['index'], inplace=True)

# %%
ds
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0        1002       Abed       Nadir  456-643-9775   93 West Main Street
# 1        1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 2        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 3        1016        Ron     Weasley  456-545-5421  2395 Hogwarts Avenue
#
#   Paying Customer        Street_Address    State Zip_Code
# 0              No   93 West Main Street  Not Avl  Not Avl
# 1               N         98 Clue Drive  Not Avl  Not Avl
# 2               N         214 HR Avenue  Not Avl  Not Avl
# 3              No  2395 Hogwarts Avenue  Not Avl  Not Avl
